# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import statsmodels.formula.api as smf

# %%
#a)
np.random.seed(1)
x=np.random.normal(0,1,100)
y=2*x+np.random.normal(0,1,100)
df=pd.DataFrame({"x":x,"y":y})
model=smf.ols(formula="y~x-1",data=df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.798
# Model:                            OLS   Adj. R-squared (uncentered):              0.796
# Method:                 Least Squares   F-statistic:                              391.7
# Date:                Tue, 13 Apr 2021   Prob (F-statistic):                    3.46e-36
# Time:                        18:36:00   Log-Likelihood:                         -135.67
# No. Observations:                 100   AIC:                                      273.3
# Df Residuals:                      99   BIC:                                      275.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#b)np.random.seed(1)
x=np.random.normal(0,1,100)
y=2*x+np.random.normal(0,1,100)
df=pd.DataFrame({"x":x,"y":y})
model=smf.ols(formula="x~y-1",data=df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      x   R-squared (uncentered):                   0.772
# Model:                            OLS   Adj. R-squared (uncentered):              0.769
# Method:                 Least Squares   F-statistic:                              334.4
# Date:                Tue, 13 Apr 2021   Prob (F-statistic):                    1.65e-33
# Time:                        18:36:26   Log-Likelihood:                         -68.570
# No. Observations:                 100   AIC:                                      139.1
# Df Residuals:                      99   BIC:                                      141.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [raw]
# In both cases thr p value are almost same there is high r2 score implying that the model is linear.

# %% [raw]
# E:In d we replace x with y and vice versa and see that the equation remains same.

# %%
np.random.seed(1)
x=np.random.normal(0,1,100)
y=2*x+np.random.normal(0,1,100)
df=pd.DataFrame({"x":x,"y":y})
model=smf.ols(formula="y~x",data=df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.800
# Model:                            OLS   Adj. R-squared:                  0.798
# Method:                 Least Squares   F-statistic:                     391.4
# Date:                Tue, 13 Apr 2021   Prob (F-statistic):           5.39e-36
# Time:                        18:45:08   Log-Likelihood:                -134.44
# No. Observations:                 100   AIC:                             272.9
# Df Residuals:                      98   BIC:                             278.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1470      0.094      1.564      0.121      -0.039       0.334
# ...

# %%
x=np.random.normal(0,1,100)
y=2*x+np.random.normal(0,1,100)
df=pd.DataFrame({"x":x,"y":y})
model=smf.ols(formula="x~y",data=df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      x   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.769
# Method:                 Least Squares   F-statistic:                     331.1
# Date:                Tue, 13 Apr 2021   Prob (F-statistic):           3.42e-33
# Time:                        18:45:18   Log-Likelihood:                -68.547
# No. Observations:                 100   AIC:                             141.1
# Df Residuals:                      98   BIC:                             146.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0101      0.049      0.208      0.835      -0.086       0.106
# ...
